# %%
import pandas as pd

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Dell'

# %%
df=pd.read_csv("Housing-2-1.csv")

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
## one hot encoding for categorical columns 
df_encode=pd.get_dummies(df,drop_first=True)

# %%
df_encode
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0    13300000  7420         4          2        3        2          True
# 1    12250000  8960         4          4        4        3          True
# 2    12250000  9960         3          2        2        2          True
# 3    12215000  7500         4          2        2        3          True
# 4    11410000  7420         4          1        2        2          True
# ..        ...   ...       ...        ...      ...      ...           ...
# 540   1820000  3000         2          1        1        2          True
# 541   1767150  2400         3          1        1        0         False
# 542   1750000  3620         2          1        1        0          True
# 543   1750000  2910         3          1        1        0         False
# 544   1750000  3850         3          1        2        0          True
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# ...

# %%
## split the data into train and test 
##into independent(X) and dependent (y)
X=df_encode.drop(["price","bedrooms","furnishingstatus_semi-furnished"],axis=1)
y=df_encode["price"]

# %%
X
# Out:
#      area  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 0    7420          2        3        2             1              0
# 1    8960          4        4        3             1              0
# 2    9960          2        2        2             1              0
# 3    7500          2        2        3             1              0
# 4    7420          1        2        2             1              1
# ..    ...        ...      ...      ...           ...            ...
# 540  3000          1        1        2             1              0
# 541  2400          1        1        0             0              0
# 542  3620          1        1        0             1              0
# 543  2910          1        1        0             0              0
# 544  3850          1        2        0             1              0
#
#      basement_yes  hotwaterheating_yes  airconditioning_yes  prefarea_yes  \
# 0               0                    0                    1             1
# ...

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int32

# %%
## split the data into test and train
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=45)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
## INPUT FEATURES SHOULD ALWAYS BE A DATAFRAME

# %%
##TRAIN TE MODEL

# %%
model=LinearRegression()

# %% [markdown]
# model

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
## predict the values from 
y_predict=model.predict(X_test)

# %%
y_predict
# Out:
# array([2027691.31803627, 5017256.31670756, 2513567.37995356,
#        5319893.47883502, 2677361.14724195, 5081361.87397332,
#        4930942.32652208, 3673876.35153117, 4090784.79400693,
#        2935207.0883543 , 2998939.47575741, 6517633.29445126,
#        6186984.4454224 , 4837192.91039064, 3242448.21092034,
#        3610460.38621811, 2035711.27991711, 2887790.51188143,
#        4005327.98514165, 5684267.30687557, 2958839.66635323,
#        6026375.68865475, 3919076.89855351, 4386239.11965484,
#        2599549.50276527, 4309514.25569222, 8013263.66472612,
#        3195967.33463683, 3682511.68874092, 5089172.77024592,
#        5095581.04437283, 3127258.8658508 , 4081516.40208657,
#        2883799.24560912, 6552961.71379969, 2823630.81683473,
#        7852841.46187284, 6362221.40749381, 5010135.99399413,
#        7375616.08296393, 4692335.628303  , 5624455.31444521,
#        5378093.98910955, 5669487.15836965, 9974234.38796024,
# ...

# %%
## evaluation of the model

# %%
mae=mean_absolute_error(y_test,y_predict
                       )

# %%
mae
# Out:
# 821439.9687556374

# %% [markdown]
# mse=mean_squared_error(y_test,y_predict)

# %%
mse=mean_squared_error(y_test,y_predict)

# %%
mse
# Out:
# 1133529542432.3948

# %%
r2=r2_score(y_test,y_predict)

# %%
r2
# Out:
# 0.627913352269625

# %%
import numpy as np

# %%
mape=np.mean(np.abs((y_test-y_predict)/y_test))*100

# %%
mape
# Out:
# 18.3211772116245

# %%
print("r2 score is :",r2)
print ("mape is :",mape)
print("mae is :",mae)
print("mse is :",mse)
# Out:
# r2 score is : 0.627913352269625
# mape is : 18.3211772116245
# mae is : 821439.9687556374
# mse is : 1133529542432.3948

# %%
print("y intercept is ",model.intercept_)## c value 
print("slope is ",model.coef_[0])
# Out:
# y intercept is  142348.47463464644
# slope is  267.33206269455746

# %%
##ordinary least square method

# %%
import statsmodels.api as sm

# %%
X=sm.add_constant(X)

# %%
model_sm=sm.OLS(y,X).fit()

# %%
df_encode=df_encode.apply(pd.to_numeric,errors="coerce").astype(int)

# %%
df_encode
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0    13300000  7420         4          2        3        2             1
# 1    12250000  8960         4          4        4        3             1
# 2    12250000  9960         3          2        2        2             1
# 3    12215000  7500         4          2        2        3             1
# 4    11410000  7420         4          1        2        2             1
# ..        ...   ...       ...        ...      ...      ...           ...
# 540   1820000  3000         2          1        1        2             1
# 541   1767150  2400         3          1        1        0             0
# 542   1750000  3620         2          1        1        0             1
# 543   1750000  2910         3          1        1        0             0
# 544   1750000  3850         3          1        2        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# ...

# %%
model_sm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     87.52
# Date:                Sat, 28 Jun 2025   Prob (F-statistic):          9.07e-123
# Time:                        16:23:00   Log-Likelihood:                -8331.5
# No. Observations:                 545   AIC:                         1.669e+04
# Df Residuals:                     531   BIC:                         1.675e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
result=pd.DataFrame({"Actual":y_test,"Predicted":y_predict})

# %%
result
# Out:
#       Actual     Predicted
# 510  2520000  2.027691e+06
# 179  5215000  5.017256e+06
# 482  2940000  2.513567e+06
# 342  3850000  5.319893e+06
# 491  2835000  2.677361e+06
# ..       ...           ...
# 25   8540000  8.123261e+06
# 413  3430000  4.765870e+06
# 512  2520000  3.252237e+06
# 389  3500000  3.679968e+06
# 258  4480000  3.831602e+06
#
# [137 rows x 2 columns]

# %%
result["diff"]=result["Actual"]-result["Predicted"]

# %%
result["diff_square"]=result["diff"]*result["diff"]

# %%
result
# Out:
#       Actual     Predicted          diff   diff_square
# 510  2520000  2.027691e+06  4.923087e+05  2.423678e+11
# 179  5215000  5.017256e+06  1.977437e+05  3.910256e+10
# 482  2940000  2.513567e+06  4.264326e+05  1.818448e+11
# 342  3850000  5.319893e+06 -1.469893e+06  2.160587e+12
# 491  2835000  2.677361e+06  1.576389e+05  2.485001e+10
# ..       ...           ...           ...           ...
# 25   8540000  8.123261e+06  4.167386e+05  1.736711e+11
# 413  3430000  4.765870e+06 -1.335870e+06  1.784548e+12
# 512  2520000  3.252237e+06 -7.322366e+05  5.361705e+11
# 389  3500000  3.679968e+06 -1.799679e+05  3.238846e+10
# 258  4480000  3.831602e+06  6.483977e+05  4.204196e+11
#
# [137 rows x 4 columns]

# %%
mse=result["diff_square"].mean()

# %%
mse
# Out:
# 1133529542432.3948

# %%
mae=result["diff"].mean()

# %%
mae
# Out:
# 10948.971377429369
